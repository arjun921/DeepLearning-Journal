# %% [markdown]
# # Housing prices Exercise

# %%
# imports
import numpy as np
from tensorflow import keras

# %%
# presuming 50K+50k per bedroom, 1bhk=100k, 2bhk=150k, etc 
# build a model
def house_model(y_new):
    xs = np.array([i for i in range(10)],dtype=float)
    ys = np.array([0.50+(j*0.50) for j in range(10)],dtype=float)
    model = keras.Sequential([
        keras.layers.Dense(units=1, input_shape=[1])
    ])
    model.compile(loss='mse',optimizer='sgd')
    model.fit(xs,ys,epochs=2000)
    return model.predict(y_new)[0]

# %%
house_model([7.0])
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 982us/step - loss: 19.8439
# Epoch 2/2000
# 1/1 [==============================] - 0s 760us/step - loss: 3.5219
# Epoch 3/2000
# 1/1 [==============================] - 0s 885us/step - loss: 0.7010
# Epoch 4/2000
# 1/1 [==============================] - 0s 867us/step - loss: 0.2126
# Epoch 5/2000
# 1/1 [==============================] - 0s 891us/step - loss: 0.1272
# Epoch 6/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1114
# Epoch 7/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1077
# Epoch 8/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1061
# Epoch 9/2000
# 1/1 [==============================] - 0s 859us/step - loss: 0.1048
# Epoch 10/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1036
# Epoch 11/2000
# 1/1 [==============================] - 0s 998us/step - loss: 0.1024
# Epoch 12/2000
# ...

# %%
# !git add .
# !git commit -m "saving week 1 exercise with accepted answer"
# !git push
# Out:
# [master 44eca19] saving week 1 exercise
#  1 file changed, 30 insertions(+), 5 deletions(-)
# Counting objects: 6, done.
# Delta compression using up to 32 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (6/6), 978 bytes | 978.00 KiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:arjun921/dl-refresher.git
#    5da5654..44eca19  master -> master
